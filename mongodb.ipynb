# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinkumarSakthivel/PROJECT-1/blob/main/mongodb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 8.8 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.5.0

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://Sachin:Sachin1748@cluster0.bb3hltm.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import pymongo
from pymongo.mongo_client import MongoClient

# %%
client=MongoClient("mongodb+srv://Sachin:Sachin1748@cluster0.bb3hltm.mongodb.net/?retryWrites=true&w=majority").dtt.guvi

# %%
client.insert_many([{'kind': 'youtube#channelListResponse',
 'etag': 'AxM-evq7dizEH-Dc9mfGIOgGcyA',
 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
 'items': [{'kind': 'youtube#channel',
   'etag': 'CelTMzdW8fZ52-9lxmnhZPsK8xU',
   'id': 'UCduIoIMfD8tT3KoU0-zBRgQ',
   'snippet': {'title': 'GUVI',
    'description': 'GUVI is an IIT-M & IIM-A incubated edu-tech company that offers Wide range of online Tech courses in your Native language.\nWith 100% placement support, Globally recognized certifications, Mentors from top global product companies  and Platforms improve your Programming and IT skills GUVI does it all. With over 18 Lakh+ learners and 9+ years of experience we provide apex learning through our Edu-tech services, GUVI shares its most loved Tech-videos on YouTube!\n\nWhat’s on our YouTube Channel?\nCareer guidance videos that give an idea for beginners & early professionals to upgrade their careers.\nNew initiatives & offers that unlock your flexible path for learning the latest technologies.\nWalkthrough videos of our practice platforms that shape up your coding & web development skills.\n\nKnow more by visiting our official website - www.guvi.in\n\n',
    'customUrl': '@guvisharing',
    'publishedAt': '2012-06-20T09:27:56Z',
    'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/jm7j9zyQfWfFW5C-bKCSjs-b5jWRnk2U_1_4GcIwkbf_wGffvR_dVcdn77U5ROuApqrhJN0Zag=s88-c-k-c0x00ffffff-no-rj',
      'width': 88,
      'height': 88},
     'medium': {'url': 'https://yt3.ggpht.com/jm7j9zyQfWfFW5C-bKCSjs-b5jWRnk2U_1_4GcIwkbf_wGffvR_dVcdn77U5ROuApqrhJN0Zag=s240-c-k-c0x00ffffff-no-rj',
      'width': 240,
      'height': 240},
     'high': {'url': 'https://yt3.ggpht.com/jm7j9zyQfWfFW5C-bKCSjs-b5jWRnk2U_1_4GcIwkbf_wGffvR_dVcdn77U5ROuApqrhJN0Zag=s800-c-k-c0x00ffffff-no-rj',
      'width': 800,
      'height': 800}},
    'localized': {'title': 'GUVI',
     'description': 'GUVI is an IIT-M & IIM-A incubated edu-tech company that offers Wide range of online Tech courses in your Native language.\nWith 100% placement support, Globally recognized certifications, Mentors from top global product companies  and Platforms improve your Programming and IT skills GUVI does it all. With over 18 Lakh+ learners and 9+ years of experience we provide apex learning through our Edu-tech services, GUVI shares its most loved Tech-videos on YouTube!\n\nWhat’s on our YouTube Channel?\nCareer guidance videos that give an idea for beginners & early professionals to upgrade their careers.\nNew initiatives & offers that unlock your flexible path for learning the latest technologies.\nWalkthrough videos of our practice platforms that shape up your coding & web development skills.\n\nKnow more by visiting our official website - www.guvi.in\n\n'},
    'country': 'IN'},
   'contentDetails': {'relatedPlaylists': {'likes': '',
     'uploads': 'UUduIoIMfD8tT3KoU0-zBRgQ'}},
   'statistics': {'viewCount': '3205405',
    'subscriberCount': '163000',
    'hiddenSubscriberCount': False,
    'videoCount': '1205'}}]}])

# %%
client.insert_one({"name":"sachin"})

# %%
db=client.dtt
history=db.newcoll
history.insert_one({"skills":"python"})

# %%
history.insert_one({"name":"vaishu",
                    "id":1234,
                    "spouse":"sachin",
                    "skills": {"python":"1","sql": "2","pandas":"3"}


                    })

# %%
history.insert_many([
    {"name":"sachin",
    "no":12345,
     "spouse":"vaishu"
    },
    {"_id":123,"name":"papaya"},
    {"name":"golden"},
    {"name": "april"}






])
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-18-373054533080> in <cell line: 1>()
# ----> 1 history.insert_many([
#       2     {"name":"sachin",
#       3     "no":12345,
#       4      "spouse":"vaishu"
#       5     },
#
# /usr/local/lib/python3.10/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     106                 with _TimeoutContext(timeout):
#     107                     return func(self, *args, **kwargs)
# --> 108         return func(self, *args, **kwargs)
#     109
#     110     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     755         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     756         blk.ops = list(gen())
# --> 757         blk.execute(write_concern, session=session)
#     758         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     759
#
# /usr/local/lib/python3.10/dist-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     578                 return None
#     579         else:
# --> 580             return self.execute_command(generator, write_concern, session)
#
# /usr/local/lib/python3.10/dist-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     448
#     449         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 450             _raise_bulk_write_error(full_result)
#     451         return full_result
#     452
#
# /usr/local/lib/python3.10/dist-packages/pymongo/bulk.py in _raise_bulk_write_error(full_result)
#     158     if full_result["writeErrors"]:
#     159         full_result["writeErrors"].sort(key=lambda error: error["index"])
# --> 160     raise BulkWriteError(full_result)
#     161
#     162
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 1, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: dtt.newcoll.dtt.newcoll index: _id_ dup key: { _id: 123 }', 'keyPattern': {'_id': 1}, 'keyValue': {'_id': 123}, 'op': {'_id': 123, 'name': 'papaya'}}], 'writeConcernErrors': [], 'nInserted': 1, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %%
name=input()
no=int(input())
try:
  history.insert_one({"_id":name,"mob":no})
  print("done")
except:
  print("the name already exists")
# Out:
# sachin
# 12345
# done

# %%
from PIL import Image
import io

# %%
photo=Image.open("/content/new.jpg")
photo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400>

# %%
new=io.BytesIO()
photo.save(new,format="JPEG")
dic={
    "name":"sachin ",
    "im":new.getvalue()
}
history.insert_one(dic)

# %%
op=history.find_one({"name":"sachin "})
print(op)
# Out:
# {'_id': ObjectId('650d0de3cf63ca96db2a7bbc'), 'name': 'sachin ', 'im': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01\x90\x02X\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf0:(\xa2\xa4\x90\xa2\x8a(\x00\xa4\xa5\xa2\x80\x12\x8aZ(\x01(\xa5\xa2\x80\x12\x8aZ(\x00\xa2\x8aZ\x00LQKE\x00\x14R\x85\'\xb5\x18>\x94\x08J(\xa2\x80\x12\x8aZ(\x01(\xa2\x96\x81\x89\x8a(\xa5\xc5\x00%\x18\xa5\xa4\xa0\x02\x8aZJ\x00(\xa5\xa4\xa0\x02\x8a)h\x10\x94\xb4Q@\x05\x14Q@\x05\x14P(\x01\xca*t\x14\xc8\xd6\xac"Vrb\x05\x18\xa9\x05.\xda\x08\xac\xae!\xa4\xd4nqOa\xebP\xb9\xf7\xaa\x8a\x02&&\xa2&\x9e\xc6\x99[!\xa1(\xa2\x8ae\x05M\x10\xe4TB\xa7\x84sJ[\x08\xd3\xb7\x1c\n\xd2\x83\x8cV}\xb8\xe0V\x84}\x05y\xd5M\x0b\xa9&\x05Hf\xe2\xa9\xee\xa6\xbb\xf1Q\x19\xc9\t\x8f\x96^\xb5JG\xa5y3\x9a\xae\xef\x93\x8a\xd6\xee[\x89\x11\xb9\xc9&\xa1\'\x9a\x95\xf8Z\x80\x9ekX\x83\x1c\x0eM\\\x8dx\xaa\x91\x0c\xb5^N\x95\x15\x06\x87\x01Z\xd6P\xeeQ\xc5f\xa2\xe4\xd7C\xa6E\xc0\xa5KY\x034l\xedz\x1cV\xdd\xbd\xb7N)\xb6P\x02\x07\x15\xb5\x05\xb0\xc0\xe2\xbb\xe0\x84A\x14$\x0e\x957\x95\x9e\xd5y-\xf8\xe9O0q\xd2\xb4\x19\x91$\
GB'}
# {'_id': ObjectId('650d203664fa63b24e5d4e3a'), 'Product Name': 'APPLE iPhone XS Max (Silver, 64 GB)', 'Product URL': 'https://www.flipkart.com/apple-iphone-xs-max-silver-64-gb/p/itmf944ehzsh7emx?pid=MOBF944E2XAHW8V5', 'Brand': 'Apple', 'Sale Price': 89900, 'Mrp': 89900, 'Discount Percentage': 0, 'Number Of Ratings': 1454, 'Number Of Reviews': 149, 'Upc': 'MOBF944E2XAHW8V5', 'Star Rating': 4.6, 'Ram': '4 GB'}
# {'_id': ObjectId('650d203664fa63b24e5d4e3b'), 'Product Name': 'Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)', 'Product URL': 'https://www.flipkart.com/apple-iphone-xr-product-red-128-gb-includes-earpods-power-adapter/p/itmf9z7zbkvjzegf?pid=MOBF9Z7ZHQC23PWQ', 'Brand': 'Apple', 'Sale Price': 41999, 'Mrp': 52900, 'Discount Percentage': 20, 'Number Of Ratings': 79512, 'Number Of Reviews': 6796, 'Upc': 'MOBF9Z7ZHQC23PWQ', 'Star Rating': 4.6, 'Ram': '4 GB'}

# %%
price=client.find({'$and':[{"Mrp":{'$gte': 40000 }},{"Mrp":{'$lte':70000}}]},{"Product Name":1,"_id":0})
for i in price:
  print(i)
# Out:
# {'Product Name': 'APPLE iPhone 8 Plus (Gold, 64 GB)'}
# {'Product Name': 'APPLE iPhone 8 Plus (Silver, 64 GB)'}
# {'Product Name': 'APPLE iPhone 8 Plus (Space Grey, 64 GB)'}
# {'Product Name': 'Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)'}
# {'Product Name': 'Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)'}
# {'Product Name': 'Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)'}
# {'Product Name': 'Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)'}
# {'Product Name': 'Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)'}
# {'Product Name': 'Apple iPhone SE (White, 256 GB) (Includes EarPods, Power Adapter)'}
# {'Product Name': 'APPLE iPhone 12 Mini (White, 64 GB)'}
# {'Product Name': 'APPLE iPhone 12 Mini (Red, 64 GB)'}
# {'Product Name': 'APPLE iPhone 12 Mini (Black, 64 GB)'}
# {'Product Name': 'APPLE iPhone 11 (White, 128 GB)'}
# {'Product Name': 'APPLE iPhone 11 (Red, 128 GB)'}
# {'Product Name': 'APPLE iPhone SE (Black, 128 GB)'}
# {'Product Name': 'APPLE iPhone SE (White, 128 GB)'}
# {'Product Name': 'APPLE iPhone SE (Red, 128 GB)'}
# {'Product Name': 'APPLE iPhone 11 (Black, 128 GB)'}
# {'Product Name': 'APPLE iPhone 11 (Purple, 64 GB)'}
# {'Product Name': 'APPLE iPhone 11 (White, 64 GB)'}
# {'Product Name': 'APPLE iPhone 11 (Black, 64 GB)'}
# {'Product Name': 'APPLE iPhone 11 (Red, 64 GB)'}

# %%
name=client.find({"$and":[{"Mrp":{'$gte': 50000}},{"Ram":{'$eq':'2 GB'}}]},{"Product Name":1,"_id":0,"Mrp":1})
for i in name:
  print(i)
# Out:
# {'Product Name': 'APPLE iPhone 8 Plus (Space Grey, 256 GB)', 'Mrp': 84900}
# {'Product Name': 'APPLE iPhone 8 Plus (Silver, 256 GB)', 'Mrp': 84900}
# {'Product Name': 'APPLE iPhone 8 (Silver, 256 GB)', 'Mrp': 77000}
# {'Product Name': 'APPLE iPhone 8 (Gold, 256 GB)', 'Mrp': 77000}
# {'Product Name': 'APPLE iPhone 8 (Space Grey, 256 GB)', 'Mrp': 77000}
# {'Product Name': 'Apple iPhone SE (White, 256 GB) (Includes EarPods, Power Adapter)', 'Mrp': 54900}
