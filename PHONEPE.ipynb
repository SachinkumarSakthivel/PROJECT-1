# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinkumarSakthivel/PROJECT-1/blob/main/PHONEPE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 8891, done.
# remote: Counting objects: 100% (8891/8891), done.
# remote: Compressing objects: 100% (7400/7400), done.
# remote: Total 8891 (delta 2789), reused 7257 (delta 1170), pack-reused 0
# Receiving objects: 100% (8891/8891), 2.30 MiB | 5.69 MiB/s, done.
# Resolving deltas: 100% (2789/2789), done.

# %%
path='/content/pulse/data/aggregated/transaction/country/india/state/'
path1='/content/pulse/data/aggregated/user/country/india/state/'

# %%
import os
import pandas as pd
import json

# %%
data=os.listdir(path)

# %% [markdown]
# # New Section

# %%
data
# Out:
# ['assam',
#  'tripura',
#  'ladakh',
#  'kerala',
#  'manipur',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'odisha',
#  'chandigarh',
#  'sikkim',
#  'nagaland',
#  'delhi',
#  'telangana',
#  'rajasthan',
#  'mizoram',
#  'himachal-pradesh',
#  'goa',
#  'uttarakhand',
#  'haryana',
#  'maharashtra',
#  'tamil-nadu',
#  'andhra-pradesh',
#  'jharkhand',
#  'lakshadweep',
#  'punjab',
#  'karnataka',
#  'meghalaya',
#  'west-bengal',
#  'uttar-pradesh',
#  'bihar',
#  'andaman-&-nicobar-islands',
#  'arunachal-pradesh',
#  'chhattisgarh',
#  'madhya-pradesh',
#  'gujarat',
#  'jammu-&-kashmir',
#  'puducherry']

# %%
from pprint import pprint
final={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in data:
    p_s=path+i +'/'
    data1=os.listdir(p_s)
    for j in (data1):
        p_y=p_s+j+'/'
        data2=os.listdir(p_y)
        for k in (data2):
            data3=open(p_y+k,'r')
            data4=json.load(data3)
            for z in data4['data']['transactionData']:
                trans_name=z['name']
                trans_amount=z['paymentInstruments'][0]['amount']
                trans_count=z['paymentInstruments'][0]['count']
                final['State'].append(i)
                final['Year'].append(j)
                final['Transacion_count'].append(trans_count)
                final['Transacion_type'].append(trans_name)
                final['Transacion_amount'].append(trans_amount)
                final['Quater'].append(int(k.strip('.json')))
pd.DataFrame(final)
#pprint(final)
# Out:
#           State  Year  Quater           Transacion_type  Transacion_count  \
# 0     karnataka  2023       1         Merchant payments        1130908170
# 1     karnataka  2023       1     Peer-to-peer payments         596731227
# 2     karnataka  2023       1  Recharge & bill payments         115567496
# 3     karnataka  2023       1        Financial Services            541652
# 4     karnataka  2023       1                    Others            948644
# ...         ...   ...     ...                       ...               ...
# 3949    tripura  2020       3  Recharge & bill payments            627363
# 3950    tripura  2020       3     Peer-to-peer payments            477769
# 3951    tripura  2020       3         Merchant payments            202106
# 3952    tripura  2020       3        Financial Services              3828
# 3953    tripura  2020       3                    Others              6819
#
#       Transacion_amount
# 0          4.761839e+11
# 1          1.908849e+12
# ...

# %%
from pprint import pprint
data=os.listdir(path1)
final={'state':[],'Year':[],'Users':[], 'Mobile_brand':[],'count':[],'percentage':[], 'response_time':[],'Quater':[]}
for i in data:
  p_s=path1+i +'/'
  data1=os.listdir(p_s)
  for j in (data1):
    p_y=p_s+j+'/'
    data2=os.listdir(p_y)
    for k in (data2):
      data3=open(p_y+k,'r')
      data4=json.load(data3)
#pd.DataFrame(final)

pprint(data4)
# Out:
# {'code': 'SUCCESS',
#  'data': {'aggregated': {'appOpens': 5777908, 'registeredUsers': 376731},
#           'usersByDevice': [{'brand': 'Xiaomi',
#                              'count': 93468,
#                              'percentage': 0.24810275767059253},
#                             {'brand': 'Samsung',
#                              'count': 86403,
#                              'percentage': 0.22934932352261958},
#                             {'brand': 'Oppo',
#                              'count': 52607,
#                              'percentage': 0.1396407516238377},
#                             {'brand': 'Vivo',
#                              'count': 44208,
#                              'percentage': 0.11734632934374925},
#                             {'brand': 'Realme',
#                              'count': 33649,
#                              'percentage': 0.08931837305663723},
#                             {'brand': 'Asus',
# ...

# %%
for z in data4['data']['usersByDevice']:
  for x in range(0,len(data4['data']['usersByDevice'])):
    final['state'].append(i)
    final['Year'].append(j)
    final['Users'].append(data4['data']["aggregated"]["registeredUsers"])
    final['Mobile_brand'].append(z[x]['brand'])
    final['count'].append(z[x]['count'])
    final['percentage'].append(z[x]['percentage'])
    final['response_time'].append(data4['responseTimestamp'])
    final['Quater'].append(k.strip(int('.json')))
pd.DataFrame(final)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-0695efaf91e1> in <cell line: 1>()
#       4     final['Year'].append(j)
#       5     final['Users'].append(data4['data']["aggregated"]["registeredUsers"])
# ----> 6     final['Mobile_brand'].append(z[x]['brand'])
#       7     final['count'].append(z[x]['count'])
#       8     final['percentage'].append(z[x]['percentage'])
#
# KeyError: 0

# %%
# Out:
# 11
